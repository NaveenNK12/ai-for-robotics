# %%
import os
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread,imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
rolex =os.listdir("C:/Users/STUDENT/Downloads/rolex")

# %%
santhanam =os.listdir("C:/Users/STUDENT/Downloads/santhanam")

# %%
amar =os.listdir("C:/Users/STUDENT/Downloads/amar")

# %%
limit =10
rolex_image=[None]*limit
j=0
for i in rolex:
    if(j<limit):
        rolex_image[j]=imread("C:/Users/STUDENT/Downloads/rolex/"+i)
        j+=1
    else:
            break

# %%
imshow(rolex_image[0])

# %%
limit =10
santhanam_image=[None]*limit
j=0
for i in santhanam:
    if(j<limit):
        santhanam_image[j]=imread("C:/Users/STUDENT/Downloads/santhanam/"+i)
        j+=1
    else:
            break

# %%
imshow(santhanam_image[6])

# %%
limit =10
amar_image=[None]*limit
j=0
for i in amar:
    if(j<limit):
        amar_image[j]=imread("C:/Users/STUDENT/Downloads/amar/"+i)
        j+=1
    else:
            break

# %%
imshow(amar_image[4])

# %%
rolex_gray =[None]*limit
j=0
for i in rolex:
    if (j<limit):
        rolex_gray[j]= rgb2gray(rolex_image[j])
        j+=1
    else:
        break

# %%
rolex_gray[4].shape
# Out:
# (246, 205)

# %%
santhanam_gray =[None]*limit
j=0
for i in santhanam:
    if (j<limit):
        santhanam_gray[j]= rgb2gray(santhanam_image[j])
        j+=1
    else:
        
            break

# %%
   santhanam_gray[4].shape
# Out:
# (194, 259)

# %%
amar_gray =[None]*limit
j=0
for i in amar:
    if (j<limit):
        amar_gray[j]= rgb2gray(amar_image[j])
        j+=1
    else:
        
            break

# %%
   amar_gray[4].shape
# Out:
# (168, 300)

# %%
len_of_image_rolex =len(rolex_gray)

# %%
image_size_rolex=rolex_gray[4].shape

# %%
flat_size_rolex=image_size_rolex[0]*image_size_rolex[1]

# %%
for i in range(len_of_image__rolex):
    rolex_gray[i] = np.ndarray.flatten(rolex_gray[4]).reshape(flat_size_rolex,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [289], in <cell line: 1>()
# ----> 1 for i in range(len_of_image__rolex):
#       2     rolex_gray[i] = np.ndarray.flatten(rolex_gray[4]).reshape(flat_size_rolex,1)
#
# NameError: name 'len_of_image__rolex' is not defined

# %%
rolex_gray=np.dstack(rolex_gray)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [290], in <cell line: 1>()
# ----> 1 rolex_gray=np.dstack(rolex_gray)
#
# File <__array_function__ internals>:5, in dstack(*args, **kwargs)
#
# File ~\Anaconda\lib\site-packages\numpy\lib\shape_base.py:723, in dstack(tup)
#     721 if not isinstance(arrs, list):
#     722     arrs = [arrs]
# --> 723 return _nx.concatenate(arrs, 2)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 225 and the array at index 1 has size 150

# %%
rolex_gray = np.rollaxis(rolex_gray,axis=2,start=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [291], in <cell line: 1>()
# ----> 1 rolex_gray = np.rollaxis(rolex_gray,axis=2,start=0)
#
# File <__array_function__ internals>:5, in rollaxis(*args, **kwargs)
#
# File ~\Anaconda\lib\site-packages\numpy\core\numeric.py:1317, in rollaxis(a, axis, start)
#    1245 @array_function_dispatch(_rollaxis_dispatcher)
#    1246 def rollaxis(a, axis, start=0):
#    1247     """
#    1248     Roll the specified axis backwards, until it lies in a given position.
#    1249
#    (...)
#    1315
#    1316     """
# -> 1317     n = a.ndim
#    1318     axis = normalize_axis_index(axis, n)
#    1319     if start < 0:
#
# AttributeError: 'list' object has no attribute 'ndim'

# %%
rolex_gray =rolex_gray.reshape(len_of_image_rolex,flat_size_rolex)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [292], in <cell line: 1>()
# ----> 1 rolex_gray =rolex_gray.reshape(len_of_image_rolex,flat_size_rolex)
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
rolex_data=pd.DataFrame(rolex_gray)

# %%
rolex_data
# Out:
#                                                    0
# 0  [[0.36206313725490197, 0.36206313725490197, 0....
# 1  [[0.6903886274509804, 0.6884392156862745, 0.68...
# 2  [[0.050980392156862744, 0.050980392156862744, ...
# 3  [[0.12156862745098039, 0.11372549019607843, 0....
# 4  [[0.047563921568627446, 0.051485490196078426, ...
# 5  [[0.01683294117647059, 0.01683294117647059, 0....
# 6  [[0.3488443137254902, 0.3724262745098039, 0.33...
# 7  [[0.16364666666666666, 0.15777568627450983, 0....
# 8  [[0.09990627450980392, 0.09990627450980392, 0....
# 9  [[0.0025, 0.0025, 0.0025, 0.0025, 0.0025, 0.00...

# %%
rolex_data["label"]="rolex"

# %%
len_of_image_santhanam =len(santhanam_gray)

# %%
image_size_santhanam=santhanam_gray[4].shape

# %%
flat_size_santhanam=image_size_santhanam[0]*image_size_santhanam[1]

# %%
for i in range(len_of_image_santhanam):
    santhanam_gray[i] = np.ndarray.flatten(santhanam_gray[4]).reshape(flat_size_santhanam,1)

# %%
santhanam_gray=np.dstack(santhanam_gray)

# %%
santhanam_gray = np.rollaxis(santhanam_gray,axis=2,start=0)

# %%
santhanam_gray =santhanam_gray.reshape(len_of_image_santhanam,flat_size_santhanam)

# %%
santhanam_data=pd.DataFrame(santhanam_gray)

# %%
santhanam_data
# Out:
#       0         1         2         3         4         5         6      \
# 0  0.145246  0.145246  0.149167  0.153089  0.158677  0.162033  0.162033
# 1  0.145246  0.145246  0.149167  0.153089  0.158677  0.162033  0.162033
# 2  0.145246  0.145246  0.149167  0.153089  0.158677  0.162033  0.162033
# 3  0.145246  0.145246  0.149167  0.153089  0.158677  0.162033  0.162033
# 4  0.145246  0.145246  0.149167  0.153089  0.158677  0.162033  0.162033
# 5  0.145246  0.145246  0.149167  0.153089  0.158677  0.162033  0.162033
# 6  0.145246  0.145246  0.149167  0.153089  0.158677  0.162033  0.162033
# 7  0.145246  0.145246  0.149167  0.153089  0.158677  0.162033  0.162033
# 8  0.145246  0.145246  0.149167  0.153089  0.158677  0.162033  0.162033
# 9  0.145246  0.145246  0.149167  0.153089  0.158677  0.162033  0.162033
#
#       7         8         9      ...     50236     50237     50238     50239  \
# 0  0.166505  0.174349  0.174349  ...  0.148846  0.180815  0.127924  0.129859
# ...

# %%
santhanam_data["label"]="santhanam"

# %%
len_of_image_amar =len(amar_gray)

# %%
image_size_amar=amar_gray[4].shape

# %%
flat_size_amar=image_size_amar[0]*image_size_amar[1]

# %%
for i in range(len_of_image_amar):
    amar_gray[i] = np.ndarray.flatten(amar_gray[4]).reshape(flat_size_amar,1)

# %%
amar_gray=np.dstack(amar_gray)

# %%
amar_gray = np.rollaxis(amar_gray,axis=2,start=0)

# %%
amar_gray =amar_gray.reshape(len_of_image_amar,flat_size_amar)

# %%
amar_data=pd.DataFrame(amar_gray)

# %%
amar_data
# Out:
#       0         1         2         3         4         5         6      \
# 0  0.054031  0.054031  0.057953  0.057953  0.061874  0.061874  0.061874
# 1  0.054031  0.054031  0.057953  0.057953  0.061874  0.061874  0.061874
# 2  0.054031  0.054031  0.057953  0.057953  0.061874  0.061874  0.061874
# 3  0.054031  0.054031  0.057953  0.057953  0.061874  0.061874  0.061874
# 4  0.054031  0.054031  0.057953  0.057953  0.061874  0.061874  0.061874
# 5  0.054031  0.054031  0.057953  0.057953  0.061874  0.061874  0.061874
# 6  0.054031  0.054031  0.057953  0.057953  0.061874  0.061874  0.061874
# 7  0.054031  0.054031  0.057953  0.057953  0.061874  0.061874  0.061874
# 8  0.054031  0.054031  0.057953  0.057953  0.061874  0.061874  0.061874
# 9  0.054031  0.054031  0.057953  0.057953  0.061874  0.061874  0.061874
#
#       7         8         9      ...     50390     50391     50392     50393  \
# 0  0.065796  0.065796  0.065796  ...  0.142486  0.142486  0.142486  0.142486
# ...

# %%
amar_data["label"]="amar"

# %%
actor_1=pd.concat([rolex_data,santhanam_data])

# %%
actor=pd.concat([actor_1,amar_data])

# %%
actor
# Out:
#                                                    0      label         1  \
# 0  [[0.36206313725490197, 0.36206313725490197, 0....      rolex       NaN
# 1  [[0.6903886274509804, 0.6884392156862745, 0.68...      rolex       NaN
# 2  [[0.050980392156862744, 0.050980392156862744, ...      rolex       NaN
# 3  [[0.12156862745098039, 0.11372549019607843, 0....      rolex       NaN
# 4  [[0.047563921568627446, 0.051485490196078426, ...      rolex       NaN
# 5  [[0.01683294117647059, 0.01683294117647059, 0....      rolex       NaN
# 6  [[0.3488443137254902, 0.3724262745098039, 0.33...      rolex       NaN
# 7  [[0.16364666666666666, 0.15777568627450983, 0....      rolex       NaN
# 8  [[0.09990627450980392, 0.09990627450980392, 0....      rolex       NaN
# 9  [[0.0025, 0.0025, 0.0025, 0.0025, 0.0025, 0.00...      rolex       NaN
# 0                                           0.145246  santhanam  0.145246
# 1                                           0.145246  santhanam  0.145246
# ...

# %%
from sklearn.utils import shuffle

# %%
kollywood_indexed=shuffle(actor).reset_index()

# %%
kollywood_indexed
# Out:
#     index                                                  0      label  \
# 0       1                                           0.054031       amar
# 1       3                                           0.054031       amar
# 2       8                                           0.145246  santhanam
# 3       4  [[0.047563921568627446, 0.051485490196078426, ...      rolex
# 4       1  [[0.6903886274509804, 0.6884392156862745, 0.68...      rolex
# 5       9                                           0.145246  santhanam
# 6       6                                           0.054031       amar
# 7       6  [[0.3488443137254902, 0.3724262745098039, 0.33...      rolex
# 8       6                                           0.145246  santhanam
# 9       2                                           0.145246  santhanam
# 10      7                                           0.054031       amar
# 11      5                                           0.145246  santhanam
# ...

# %%
kollywood_actor=kollywood_indexed.drop(['index'],axis=1)

# %%
kollywood_actor
# Out:
#                                                     0      label         1  \
# 0                                            0.054031       amar  0.054031
# 1                                            0.054031       amar  0.054031
# 2                                            0.145246  santhanam  0.145246
# 3   [[0.047563921568627446, 0.051485490196078426, ...      rolex       NaN
# 4   [[0.6903886274509804, 0.6884392156862745, 0.68...      rolex       NaN
# 5                                            0.145246  santhanam  0.145246
# 6                                            0.054031       amar  0.054031
# 7   [[0.3488443137254902, 0.3724262745098039, 0.33...      rolex       NaN
# 8                                            0.145246  santhanam  0.145246
# 9                                            0.145246  santhanam  0.145246
# 10                                           0.054031       amar  0.054031
# ...

# %%
x=kollywood_actor.values[:,: -1]

# %%
y=kollywood_actor.values[:, -1]

# %%
x
# Out:
# array([[array([[0.01683294, 0.01683294, 0.01402745, ..., 0.00392157, 0.00392157,
#                 0.00392157],
#                [0.01402745, 0.01402745, 0.01122196, ..., 0.00392157, 0.00392157,
#                 0.00392157],
#                [0.01122196, 0.0092498 , 0.0092498 , ..., 0.00392157, 0.00392157,
#                 0.00392157],
#                ...,
#                [0.00892157, 0.00892157, 0.00892157, ..., 0.43575176, 0.4318302 ,
#                 0.43575176],
#                [0.00697216, 0.00697216, 0.01089373, ..., 0.42762588, 0.41586118,
#                 0.41586118],
#                [0.00697216, 0.00697216, 0.00697216, ..., 0.41978275, 0.4001749 ,
#                 0.3884102 ]])                                                   ,
#         nan, nan, ..., nan, nan, nan],
#        [0.05403098039215686, 0.05403098039215686, 0.05795254901960785,
#         ..., 0.14248588235294118, 0.14248588235294118,
#         0.14248588235294118],
# ...

# %%
y
# Out:
# array([0.14248588235294118, 0.14248588235294118, nan, nan, nan, nan,
#        0.14248588235294118, nan, nan, nan, 0.14248588235294118, nan, nan,
#        nan, nan, nan, 0.14248588235294118, nan, nan, nan,
#        0.14248588235294118, nan, nan, 0.14248588235294118,
#        0.14248588235294118, nan, 0.14248588235294118, 0.14248588235294118,
#        nan, nan], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %% [raw]
# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn import svm

# %%
clf=svm.SVC()

# %%
clf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [227], in <cell line: 1>()
# ----> 1 clf.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined

# %%
y-pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [229], in <cell line: 1>()
# ----> 1 y-pred
#
# NameError: name 'pred' is not defined

# %%
for i in (np.random.randint(0,6,4)):
    predicted_images=(np.reshape(x_test[i],(512,512))).astype(np.flot64))
